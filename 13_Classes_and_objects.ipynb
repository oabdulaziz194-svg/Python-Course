# %%
class Employee:
    # attributes
    empCount = 0
    
    # methods
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        Employee.empCount += 1
    
    def displayCount(self):
        print (Employee.empCount)
    
    def displayEmployee(self):
        print ("Name:", self.name, " and Salayar: ", self.salary)

emp1 = Employee('Abdulhakeem', 100)

# %%
emp1.displayCount()
# Out:
# 1

# %%
emp2 = Employee('Hasan', 200)

# %%
emp1.displayCount()
# Out:
# 2

# %%
emp1.displayEmployee()
# Out:
# Name: Abdulhakeem  and Salayar:  100

# %%
emp2.displayEmployee()
# Out:
# Name: Hasan  and Salayar:  200

# %%
emp1.age = 30

# %%
emp1.age
# Out:
# 30

# %%
emp1.displayEmployee()
# Out:
# Name: Abdulhakeem  and Salayar:  100

# %%
emp2.age
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 emp2.age
#
# AttributeError: 'Employee' object has no attribute 'age'

# %%
del emp1.age

# %%
emp1.age
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 emp1.age
#
# AttributeError: 'Employee' object has no attribute 'age'

# %%
emp2.age = 23

# %%
emp2.age
# Out:
# 23

# %%
delattr(emp2, 'age')

# %%
emp2.age
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 emp2.age
#
# AttributeError: 'Employee' object has no attribute 'age'
