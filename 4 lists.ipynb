# %%
names = ['Abdulhakeem', 'Khaled', 'Hasan', 'howidah']

# %%
print ("the list of names ", names)
# Out:
# the list of names  ['Abdulhakeem', 'Khaled', 'Hasan', 'howidah']

# %%
names[1]
# Out:
# 'Khaled'

# %%
print (names[0:4])
# Out:
# ['Abdulhakeem', 'Khaled', 'Hasan', 'howidah']

# %%
fuclties = ['FC','FS','FE','FM']
data = [names, fuclties]

# %%
data
# Out:
# [['Abdulhakeem', 'Khaled', 'Hasan', 'howidah'], ['FC', 'FS', 'FE', 'FM']]

# %%
data[0][1]
# Out:
# 'Khaled'

# %%
data[1][3]
# Out:
# 'FM'

# %%
names.append('Khaled')

# %%
data
# Out:
# [['Abdulhakeem', 'Khaled', 'Hasan', 'howidah', 'Hasan', 'Khaled'],
#  ['FC', 'FS', 'FE', 'FM']]

# %%
names.count('Khaled')
# Out:
# 2

# %%
names.append('Abdulhakeem')

# %%
names.sort()
names
# Out:
# ['Abdulhakeem', 'Abdulhakeem', 'Hasan', 'Hasan', 'Khaled', 'Khaled', 'howidah']

# %%
names.insert(2, 'ابو خالد')

# %%
names.sort()
names
# Out:
# ['Abdulhakeem',
#  'Abdulhakeem',
#  'Hasan',
#  'Hasan',
#  'Khaled',
#  'Khaled',
#  'howidah',
#  'ابو خالد']

# %%
names.remove('Khaled')

# %%
names
# Out:
# ['Abdulhakeem',
#  'Abdulhakeem',
#  'Hasan',
#  'Hasan',
#  'Khaled',
#  'howidah',
#  'ابو خالد']

# %%
names.reverse()
names
# Out:
# ['ابو خالد',
#  'howidah',
#  'Khaled',
#  'Hasan',
#  'Hasan',
#  'Abdulhakeem',
#  'Abdulhakeem']

# %%
del names[0]

# %%
names
# Out:
# ['howidah', 'Khaled', 'Hasan', 'Hasan', 'Abdulhakeem', 'Abdulhakeem']

# %%
data
# Out:
# [['howidah', 'Khaled', 'Hasan', 'Hasan', 'Abdulhakeem', 'Abdulhakeem'],
#  ['FC', 'FS', 'FE', 'FM']]

# %%
len(data)
# Out:
# 2

# %%
min(names)
# Out:
# 'Abdulhakeem'
