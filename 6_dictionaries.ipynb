# %%
name_fuclties = {'Abdulhakeem':'FC',
                'Khaled':'FM',
                'Fuad':'FE',
                'Khaled':'FS'}
name_fuclties
# Out:
# {'Abdulhakeem': 'FC', 'Khaled': 'FS', 'Fuad': 'FE'}

# %%
name_fuclties['Abdulhakeem']
# Out:
# 'FC'

# %%
len(name_fuclties)
# Out:
# 3

# %%
del name_fuclties['Abdulhakeem']

# %%
name_fuclties
# Out:
# {'Khaled': 'FS', 'Fuad': 'FE'}

# %%
name_fuclties['Abdulhakeem'] = 'Fuclty of Science'

# %%
name_fuclties
# Out:
# {'Khaled': 'FS', 'Fuad': 'FE', 'Abdulhakeem': 'Fuclty of Science'}

# %%
name_fuclties['Khaled']
# Out:
# 'FS'

# %%
name_fuclties.get('Khaled')
# Out:
# 'FS'

# %%
name_fuclties.keys()
# Out:
# dict_keys(['Khaled', 'Fuad', 'Abdulhakeem'])

# %%
name_fuclties_course = {'Abdulhakeem': ['FC', 'CS'],
                      'Khaled ': ['FM', 'GM'],
                      'Fuad' : ['FE', 'EE'],
                      'Khaled ': ['FS', 'SC']}
name_fuclties_course
# Out:
# {'Abdulhakeem': ['FC', 'CS'], 'Khaled ': ['FS', 'SC'], 'Fuad': ['FE', 'EE']}

# %%
name_fuclties_course['Abdulhakeem'][1]
# Out:
# 'CS'
