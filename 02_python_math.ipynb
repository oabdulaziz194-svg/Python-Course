# %%
1+2
# Out:
# 3

# %%
1998-2025
# Out:
# -27

# %%
x=27
y=2025

# %%
x-y
# Out:
# -1998

# %%
x+y
# Out:
# 2052

# %%
x * y
# Out:
# 54675

# %%
x|y
# Out:
# 2043

# %%
x // y
# Out:
# 0

# %%
26 | y
# Out:
# 2043

# %%
26 + y
# Out:
# 2051

# %%
22 + 3 * 6 - 77
# Out:
# -37
