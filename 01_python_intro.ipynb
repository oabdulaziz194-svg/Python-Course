# %%
import sys
import os 
import random

# %%
print ("Hello AbuKhaled")
# Out:
# Hello AbuKhaled

# %%
print ('السلام عليكم كيف حالك يابو خالد ')
# Out:
# السلام عليكم كيف حالك يابو خالد

# %%
#chis of commnet

# %%
name ="AbuKhaled"

# %%
name
# Out:
# 'AbuKhaled'

# %%
number=2025
number
# Out:
# 2025

# %%
number
# Out:
# 2025

# %%
list =["بسم ","الله ","الرحمن ","الرحيم"]
list
# Out:
# ['بسم ', 'الله ', 'الرحمن ', 'الرحيم']

# %%
tuple = ("بسم","الله","الرحمن","الرحيم")
tuple
# Out:
# ('بسم', 'الله', 'الرحمن', 'الرحيم')

# %%
dict ={1:"Abdulhakeem",2:"Khaled",3:"Hasan"}

# %%
dict
# Out:
# {1: 'Abdulhakeem', 2: 'Khaled', 3: 'Hasan'}
