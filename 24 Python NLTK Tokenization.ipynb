# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
ar_text = "بسم الله الرحمن الرحيم"

# %%
ar_text.split()
# Out:
# ['بسم', 'الله', 'الرحمن', 'الرحيم']

# %%
for word in ar_text.split():
    print(word)
# Out:
# بسم
# الله
# الرحمن
# الرحيم
