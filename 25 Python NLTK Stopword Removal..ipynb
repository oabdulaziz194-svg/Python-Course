# %%
from nltk.tokenize import word_tokenize

# %%
stop = [
"i","me","my","myself","we","our","ours","ourselves","you","your","yours",
"yourself","yourselves","he","him","his","himself","she","her","hers",
"herself","it","its","itself","they","them","their","theirs","themselves",
"what","which","who","whom","this","that","these","those","am","is","are",
"was","were","be","been","being","have","has","had","having","do","does",
"did","doing","a","an","the","and","but","if","or","because","as","until",
"while","of","at","by","for","with","about","against","between","into",
"through","during","before","after","above","below","to","from","up",
"down","in","out","on","off","over","under","again","further","then",
"once","here","there","when","where","why","how","all","any","both",
"each","few","more","most","other","some","such","no","nor","not",
"only","own","same","so","than","too","very"
]

# %%
sent = "this is an example where we can remove stop words and filter the sentence to be more useful."

# %%
words = sent.split()
words
# Out:
# ['this',
#  'is',
#  'an',
#  'example',
#  'where',
#  'we',
#  'can',
#  'remove',
#  'stop',
#  'words',
#  'and',
#  'filter',
#  'the',
#  'sentence',
#  'to',
#  'be',
#  'more',
#  'useful.']

# %%
filtered = []

for word in words:
    if word not in stop:
        filtered.append(word)

filtered
# Out:
# ['example', 'can', 'remove', 'stop', 'words', 'filter', 'sentence', 'useful.']

# %%
#هذا مثال عربي

# %%
ar_stop_words = ["في","على","من","إلى","أن","و","أو","كان","كانت","هو","هي"]

ar_sent = "قامت القوات البحرية بمحاصرة العدو ليلا أثناء الحرب الباردة في أوائل القرن السابع على أن يتم فك حصار مدينة."

words = ar_sent.split()

filtered = []

for word in words:
    if word not in ar_stop_words:
        filtered.append(word)

filtered
# Out:
# ['قامت',
#  'القوات',
#  'البحرية',
#  'بمحاصرة',
#  'العدو',
#  'ليلا',
#  'أثناء',
#  'الحرب',
#  'الباردة',
#  'أوائل',
#  'القرن',
#  'السابع',
#  'يتم',
#  'فك',
#  'حصار',
#  'مدينة.']
