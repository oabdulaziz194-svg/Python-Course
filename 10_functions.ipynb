# %%
def add(x, y):
    return x + y

# %%
add(4,8)
# Out:
# 12

# %%
add(4,5)
# Out:
# 9

# %%
list = [1,2,3]

def modify(list):
    list.append([4,5,6])
    return list

print (modify(list))
print (list)
# Out:
# [1, 2, 3, [4, 5, 6]]
# [1, 2, 3, [4, 5, 6]]

# %%
list = [1,2,3]

def modify(list):
    print (list)
    list = [4,5,6]
    return list

print (modify(list))
print (list)
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [1, 2, 3]

# %%
def getData(name, age):
    print ("Name: ", name)
    print ("Age: ", age)

getData(name="AbuKhaled", age="25")
# Out:
# Name:  AbuKhaled
# Age:  25

# %%
def getData(name, age=0):
    print ("Name: ", name)
    print ("Age: ", age)

getData(name="AbuKhaled")
# Out:
# Name:  AbuKhaled
# Age:  0

# %%
def getData(x, *vars):
    print (x)
    for var in vars:
        print (var)
    print ("\n")

getData(133)
# Out:
# 133

# %%
getData(133,33,444)
# Out:
# 133
# 33
# 444

# %%
multiply = lambda x,y: x*y

# %%
multiply(3,83)
# Out:
# 249

# %%
total = 0

def sum(x,y):
    total = x + y
    return total

print(sum(9,7))
print (total)
# Out:
# 16
# 0

# %%
total = 0

def sum(x,y):
    global total
    total = x + y
    return total

print(sum(9,7))
print (total)
# Out:
# 16
# 16
