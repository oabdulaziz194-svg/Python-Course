# %%
tuple = (3, 1, 4, 1, 5, 9)
tuple
# Out:
# (3, 1, 4, 1, 5, 9)

# %%
tuple[0]
# Out:
# 3

# %%
tuple[:4]
# Out:
# (3, 1, 4, 1)

# %%
list(tuple)
# Out:
# [3, 1, 4, 1, 5, 9]

# %%
tuple
# Out:
# (3, 1, 4, 1, 5, 9)

# %%
tuple[0] = 44
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 tuple[0] = 4
#
# TypeError: 'tuple' object does not support item assignment

# %%
list = list(tuple)

# %%
list
# Out:
# [3, 1, 4, 1, 5, 9]

# %%
list[0] = 44

# %%
list
# Out:
# [44, 1, 4, 1, 5, 9]
